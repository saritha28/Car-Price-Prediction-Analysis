# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\sarit\\Downloads\\Algorithms_projects\\carprice.csv')

# %%
df.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['ID', 'symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
#        'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   name              205 non-null    object
#  3   fueltypes         205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumbers       205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheels       205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# ID                205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# ...

# %%
df['name'].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: name, Length: 147, dtype: int64

# %%
df['fueltypes'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltypes, dtype: int64

# %% [markdown]
# We can see that there are 185 gas fueltype cars and 20 diesel cars

# %% [markdown]
# # EDA

# %% [markdown]
# ### Categorical Variables

# %%
#Univariate Analysis

plt.figure(figsize=(8,6))
sns.countplot(x='fueltypes',data=df,palette='mako')
plt.xlabel('fueltypes',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='doornumbers',data=df,palette='mako')
plt.xlabel('doornumbers',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='carbody',data=df,palette='mako')
plt.xlabel('carbody',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='drivewheels',data=df,palette='mako')
plt.xlabel('drivewheels',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='enginelocation',data=df,palette='mako')
plt.xlabel('enginelocation',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='cylindernumber',data=df,palette='mako')
plt.xlabel('cylindernumber',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='enginetype',data=df,palette='mako')
plt.xlabel('enginetype',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='fuelsystem',data=df,palette='mako')
plt.xlabel('fuelsystem',fontsize=15)
plt.show()

# %% [markdown]
# ### Numerical Variables

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   name              205 non-null    object
#  3   fueltypes         205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumbers       205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheels       205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
#Univariate Analysis

sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['symboling'],kde=True,color='blue',bins=10,label=None)

# %%
sns.set(rc={"figure.figsize":(8,6)})
ax =sns.distplot(df['wheelbase'],kde=True,color='blue',bins=10)
ax.grid(True,linestyle='--',alpha=0.7)
plt.show()

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['carwidth'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['carheight'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['curbweight'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['enginesize'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['boreratio'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['stroke'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['compressionratio'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['horsepower'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['peakrpm'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['citympg'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['highwaympg'],kde=True, color='blue',bins=10)

# %%
sns.set(rc={"figure.figsize":(8,6)})
sns.distplot(df['price'],kde=True, color='blue',bins=10)

# %% [markdown]
# ### Findinga and Removing Outliers

# %%
df.isnull().sum()
# Out:
# ID                  0
# symboling           0
# name                0
# fueltypes           0
# aspiration          0
# doornumbers         0
# carbody             0
# drivewheels         0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Finding outliers
numeric_cols= df.select_dtypes(include=['int64','float64'])
plt.figure(figsize=(18,10))
sns.boxplot(data=numeric_cols)
plt.show()

# %% [markdown]
# We can find outliers in the price column.We need to work on outliers.

# %%
def remove_outliers(cols):
    sorted(cols)
    Q1,Q3 = cols.quantile([0.25,0.75])
    IQR = Q3-Q1
    lower_range = Q1 - (1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
for i in numeric_cols.columns:
    lower_range,upper_range = remove_outliers(df[i])
    df[i] = np.where(df[i] > upper_range,upper_range,df[i])
    df[i] = np.where(df[i] < lower_range,lower_range,df[i])

# %%
#Again finding outliers
numeric_cols = df.select_dtypes(include=(['int64','float64']))
plt.figure(figsize=(20,10))
sns.boxplot(data=numeric_cols)
plt.show()

# %% [markdown]
# Now we can see that there are no outliers in the numeric columns.

# %%
plt.boxplot(df['compressionratio'])
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
#Price vs fueltype
plt.figure(figsize=(8,5))
sns.barplot(y='price',x='fueltypes',data=df)
plt.title('Prive vs Fueltype')
plt.xlabel('Fueltype')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# We can observe that there is high price for diesel cars compared to gas car.

# %%
#Price vs Aspiration
plt.figure(figsize=(8,5))
sns.barplot(x='aspiration',y='price',data=df)
plt.title('Prive vs Aspiration')
plt.xlabel('Aspiration')
plt.ylabel('Price')
plt.show()

# %%
#Price vs Doornumber
plt.figure(figsize=(8,5))
sns.barplot(x='doornumbers',y='price',data=df)
plt.title('Prive vs Doornumber')
plt.xlabel('Doornumbers')
plt.ylabel('Price')
plt.show()

# %%
#Price vs Carbody
plt.figure(figsize=(10,6))
sns.barplot(x='carbody',y='price',data=df)
plt.title('Prive vs Carbody')
plt.xlabel('Carbody')
plt.ylabel('Price')
plt.show()

# %%
#Price vs Drivewheels
plt.figure(figsize=(8,5))
sns.barplot(x='drivewheels',y='price',data=df)
plt.title('Prive vs Drivewheel')
plt.xlabel('Drivewheel')
plt.ylabel('Price')
plt.show()

# %%
#Price vs Enginelocation
plt.figure(figsize=(8,6))
sns.barplot(x='enginelocation',y='price',data=df)
plt.title('Prive vs Enginelocation')
plt.xlabel('Enginelocation')
plt.ylabel('Price')
plt.show()

# %%
#Price vs Enginetype
plt.figure(figsize=(10,6))
sns.barplot(x='enginetype',y='price',data=df)
plt.title('Prive vs Enginetype')
plt.xlabel('Enginetype')
plt.ylabel('Price')
plt.show()

# %%
#Price vs Cylindernumber
plt.figure(figsize=(10,6))
sns.barplot(x='cylindernumber',y='price',data=df)
plt.title('Prive vs Cylindernumber')
plt.xlabel('Cylindernumber')
plt.ylabel('Price')
plt.show()

# %%
#Price vs Fuelsystem
plt.figure(figsize=(10,6))
sns.barplot(x='fuelsystem',y='price',data=df)
plt.title('Prive vs Fuelsystem')
plt.xlabel('Fuelsystem')
plt.ylabel('Price')
plt.show()

# %%
#Regression plot
#regplot is used to plot data and linear regression model.
plt.figure(figsize=(8,6))
sns.regplot(x='carlength',y='price',data=df)
plt.show()

# %%
#wheelbase v/s price
plt.figure(figsize=(8,6))
sns.regplot(x='wheelbase',y='price',data=df)
plt.show()

# %%
#carheight v/s price
plt.figure(figsize=(8,6))
sns.regplot(x='carheight',y='price',data=df)
plt.show()

# %%
#curbweight v/s price
plt.figure(figsize=(8,6))
sns.regplot(x='curbweight',y='price',data=df)
plt.show()

# %%
#boreratio v/s price
plt.figure(figsize=(8,6))
sns.regplot(x='boreratio',y='price',data=df)
plt.show()

# %%
#stroke v/s price
plt.figure(figsize=(8,6))
sns.regplot(x='stroke',y='price',data=df)
plt.show()

# %%
#compressionratio v/s price
plt.figure(figsize=(8,6))
sns.regplot(x='compressionratio',y='price',data=df)
plt.show()

# %%
##horsepower v/s price
plt.figure(figsize=(8,6))
sns.regplot(x='horsepower',y='price',data=df)
plt.show()

# %%
df.corr()
# Out:
#                         ID  symboling  wheelbase  carlength  carwidth  \
# ID                1.000000  -0.151621   0.136702   0.170636  0.059244
# symboling        -0.151621   1.000000  -0.537515  -0.357612 -0.235697
# wheelbase         0.136702  -0.537515   1.000000   0.874780  0.798179
# carlength         0.170636  -0.357612   0.874780   1.000000  0.847860
# carwidth          0.059244  -0.235697   0.798179   0.847860  1.000000
# carheight         0.255960  -0.541038   0.594171   0.491029  0.283227
# curbweight        0.071962  -0.227691   0.775265   0.877728  0.871963
# enginesize        0.006263  -0.100869   0.554028   0.701468  0.740015
# boreratio         0.260064  -0.130051   0.489113   0.606454  0.562591
# stroke           -0.157469   0.006560   0.187658   0.150695  0.206592
# compressionratio  0.158596  -0.070206   0.011208  -0.063677 -0.040546
# horsepower       -0.017595   0.064578   0.398973   0.601493  0.649449
# ...

# %%
#correlation plot
#plt.figure(figsize=(30,20))
fig,ax = plt.subplots(figsize=(20,15))
ax.set_ylim([0,50])
h=sns.heatmap(df.corr(),annot=True,cmap='crest',linewidth=.5,ax=ax,annot_kws={'fontsize':15})
h.XData={'large'}
h.YData={'large'}
# Rotate x-axis tick labels for better readability
plt.xticks(rotation=45, ha='right')
# Rotate y-axis tick labels for better readability
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()
label = df.select_dtypes(include=['object'])
df_copy= df.copy()

for i in label:
    df_copy[i] = encode.fit_transform(df_copy[i])
df_copy.shape
# Out:
# (205, 26)

# %%
df_copy.head()
# Out:
#     ID  symboling  name  fueltypes  aspiration  doornumbers  carbody  \
# 0  1.0        3.0     2          1           0            1        0
# 1  2.0        3.0     3          1           0            1        0
# 2  3.0        1.0     1          1           0            1        2
# 3  4.0        2.0     4          1           0            0        3
# 4  5.0        2.0     5          1           0            0        3
#
#    drivewheels  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0            2               0       88.6  ...       130.0           5
# 1            2               0       88.6  ...       130.0           5
# 2            2               0       94.5  ...       152.0           5
# 3            1               0       99.8  ...       109.0           5
# 4            0               0       99.4  ...       136.0           5
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %% [markdown]
# ## Feature Engineering

# %%
X = df_copy.iloc[:,2:25]
Y = df_copy.iloc[:,-1]

# %%
X.head()
# Out:
#    name  fueltypes  aspiration  doornumbers  carbody  drivewheels  \
# 0     2          1           0            1        0            2
# 1     3          1           0            1        0            2
# 2     1          1           0            1        2            2
# 3     4          1           0            0        3            1
# 4     5          1           0            0        3            0
#
#    enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# 0               0       88.6      168.8      64.1  ...               2
# 1               0       88.6      168.8      64.1  ...               2
# 2               0       94.5      171.2      65.5  ...               3
# 3               0       99.8      176.6      66.2  ...               2
# 4               0       99.4      176.6      66.4  ...               1
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
from sklearn.feature_selection import mutual_info_regression,SelectKBest,f_classif
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.decomposition import PCA

#Model
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

#Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

#Standardizing data
from sklearn.preprocessing import StandardScaler

# %%
#mutual information regression
mut_score = mutual_info_regression(X,Y)
mut_score = pd.Series(mut_score)
mut_score.index = X.columns
mut_score.sort_values(ascending=True)
# Out:
# doornumbers         0.000000
# enginelocation      0.000000
# carbody             0.049682
# fueltypes           0.101964
# aspiration          0.110163
# drivewheels         0.246986
# enginetype          0.350709
# cylindernumber      0.368477
# name                0.566629
# fuelsystem          0.626465
# carheight           0.685687
# peakrpm             0.734662
# stroke              0.894749
# boreratio           0.909404
# carwidth            0.912361
# carlength           0.929852
# curbweight          0.936603
# wheelbase           0.953209
# compressionratio    1.005233
# enginesize          1.231184
# horsepower          1.360522
# citympg             1.718999
# highwaympg          2.893633
# dtype: float64

# %%
mut_score.sort_values(ascending=False).plot.bar(figsize=(18,6))

# %% [markdown]
# ## Feature Extraction

# %%
X.head()
# Out:
#    name  fueltypes  aspiration  doornumbers  carbody  drivewheels  \
# 0     2          1           0            1        0            2
# 1     3          1           0            1        0            2
# 2     1          1           0            1        2            2
# 3     4          1           0            0        3            1
# 4     5          1           0            0        3            0
#
#    enginelocation  wheelbase  carlength  carwidth  ...  cylindernumber  \
# 0               0       88.6      168.8      64.1  ...               2
# 1               0       88.6      168.8      64.1  ...               2
# 2               0       94.5      171.2      65.5  ...               3
# 3               0       99.8      176.6      66.2  ...               2
# 4               0       99.4      176.6      66.4  ...               1
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
#creating new feature
X['engine_displacement'] = X['cylindernumber'] * X['enginesize']
X['fuel_efficiency'] = (X['citympg'] + X['highwaympg']) / 2
X['quality_index'] = (X['enginesize'] + X['horsepower'] + X['curbweight']) / 3

# %%
X.head()
# Out:
#    name  fueltypes  aspiration  doornumbers  carbody  drivewheels  \
# 0     2          1           0            1        0            2
# 1     3          1           0            1        0            2
# 2     1          1           0            1        2            2
# 3     4          1           0            0        3            1
# 4     5          1           0            0        3            0
#
#    enginelocation  wheelbase  carlength  carwidth  ...  boreratio  stroke  \
# 0               0       88.6      168.8      64.1  ...       3.47    2.68
# 1               0       88.6      168.8      64.1  ...       3.47    2.68
# 2               0       94.5      171.2      65.5  ...       2.68    3.47
# 3               0       99.8      176.6      66.2  ...       3.19    3.40
# 4               0       99.4      176.6      66.4  ...       3.19    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg  \
# ...

# %%
#mutual information regression
mut_score = mutual_info_regression(X,Y)
mut_score = pd.Series(mut_score)
mut_score.index = X.columns
mut_score.sort_values(ascending=True)
# Out:
# doornumbers            0.000000
# enginelocation         0.002018
# aspiration             0.072606
# carbody                0.078352
# fueltypes              0.130782
# drivewheels            0.260436
# enginetype             0.387500
# cylindernumber         0.416240
# name                   0.544596
# carheight              0.644817
# fuelsystem             0.697860
# peakrpm                0.771924
# carwidth               0.833613
# carlength              0.871199
# stroke                 0.871441
# quality_index          0.872456
# boreratio              0.902749
# wheelbase              0.903029
# curbweight             0.916642
# compressionratio       1.000378
# engine_displacement    1.150677
# enginesize             1.240228
# horsepower             1.357440
# citympg                1.638658
# fuel_efficiency        2.329908
# highwaympg             2.887172
# dtype: float64

# %%
mut_score.sort_values(ascending=False).plot.bar(figsize=(18,6))

# %% [markdown]
# # Data Splitting into Train and Test

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("Y_train:", Y_train.shape)
print("Y_test:", Y_test.shape)
# Out:
# X_train: (143, 26)
# X_test: (62, 26)
# Y_train: (143,)
# Y_test: (62,)

# %% [markdown]
# ### Standardize the data

# %%
scale = StandardScaler()
X_train_scale = scale.fit_transform(X_train)
X_test_scale = scale.fit_transform(X_test)

# %%
X_train_scale
# Out:
# array([[ 1.14282808,  0.30265996, -0.48245064, ..., -0.13192406,
#          0.32204447, -0.22494456],
#        [-0.36658963,  0.30265996,  2.0727509 , ...,  0.13315988,
#         -1.01280651,  0.7344121 ],
#        [ 0.85531994, -3.30403793,  2.0727509 , ..., -0.30864669,
#          0.65575721, -0.24055796],
#        ...,
#        [-0.03116347,  0.30265996, -0.48245064, ..., -0.50009621,
#          1.07289814, -1.21032356],
#        [ 1.02303302,  0.30265996, -0.48245064, ...,  1.84884208,
#         -1.01280651,  0.94779523],
#        [-0.12699951,  0.30265996, -0.48245064, ...,  2.06974537,
#         -1.34651926,  1.43528026]])

# %% [markdown]
# ## PCA

# %%
pc = PCA()
X_train_scale_pc = pc.fit_transform(X_train_scale)
X_test_scale_pc = pc.fit_transform(X_test_scale)

# %%
#Explained variance ratio 
#The explained variance ratio is an array of the variance of the 
#data explained by each of the principal components in your data. 
exp_var = pc.explained_variance_ratio_

# %%
print("Explained Variance Ratio:", exp_var)
# Out:
# Explained Variance Ratio: [3.87145902e-01 1.59460238e-01 1.00781795e-01 8.02346919e-02
#  5.02220521e-02 3.84012654e-02 3.46738352e-02 2.79801857e-02
#  2.13195977e-02 1.84856866e-02 1.68717735e-02 1.61807046e-02
#  1.05871165e-02 1.01024009e-02 7.01317580e-03 6.45561921e-03
#  4.48011856e-03 3.57051500e-03 2.15143551e-03 1.52720616e-03
#  1.15328801e-03 6.42192470e-04 4.36558714e-04 1.22645403e-04
#  1.73710511e-33 1.62652817e-33]

# %%
#Cumulative sum of eigenvalues; This will be used to create step plot
#for visualizing the variance explained by each principal component.

#Now let us calculate the cumulative sum of explained variance ratio
cum_var = np.cumsum(exp_var)

# %%
#plot the scree plot or cumulative explained variance plot
plt.plot(range(1,len(exp_var)+1),cum_var,marker='o',linestyle='-')
plt.xlabel('Number of COmponents')
plt.ylabel("Cumulative Explained Variance")
plt.title("Scree plot or Cumulative Explained Variance Plot")
plt.grid(True)
plt.show()

# %%
#cumulative explained variance 
cum_var = np.cumsum(exp_var)

#how many components to select 
#here we are capturing 95% variance
desired_var = 0.95

#how many components ca we select
num_comp = np.argmax(cum_var >= desired_var)+1

print(f"\number of components selected:{num_comp}")
# Out:
# umber of components selected:12

# %%
pc = PCA(n_components=12)
X_train_scale_pc = pc.fit_transform(X_train_scale)
X_test_scale_pc = pc.fit_transform(X_test_scale)

# %%
exp_var = pc.explained_variance_ratio_
print("Explained Variance Ratio:",exp_var)
# Out:
# Explained Variance Ratio: [0.3871459  0.15946024 0.10078179 0.08023469 0.05022205 0.03840127
#  0.03467384 0.02798019 0.0213196  0.01848569 0.01687177 0.0161807 ]

# %%
#Now let us calculate the cumulative sum of explaine variance ratio
cum_var = np.cumsum(exp_var)

# %%
#Let us plot the scree plot or cumulative explained variance plot
plt.plot(range(1,len(exp_var)+1),cum_var,marker='o',linestyle='-')
plt.xlabel('Number of components')
plt.ylabel("Cumulative Explained Variance")
plt.title("Scree plot or Cumulative Explained Variance plot")
plt.grid(True)
plt.show()

# %% [markdown]
# # Model Training

# %%
lr = LinearRegression()
lr.fit(X_train_scale_pc,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_scale_pc)
y_pred
# Out:
# array([18.17498332, 28.47326846, 30.23540439, 28.43131295, 25.69473236,
#        35.70700541, 38.46855977, 33.03992456, 30.10718938, 39.47744515,
#        27.28046264, 33.72491351, 25.37624478, 29.55677162, 16.59027311,
#        35.15849833, 44.23058006, 26.78640671, 29.88269365, 30.67367535,
#        29.24914916, 20.18899351, 35.79413353, 42.49159043, 36.51808137,
#        18.88929377, 28.3556914 , 24.97155031, 34.5197198 , 25.22443011,
#        26.2231174 , 36.14134503, 32.75266707, 19.50567643, 34.92633071,
#        27.63776343, 30.17276054, 25.5555933 , 38.42614036, 26.6281245 ,
#        30.49316387, 32.56361718, 25.82550362, 33.74111304, 34.65274983,
#        32.66214807, 36.44616434, 32.12984759, 29.54264876, 26.658654  ,
#        39.60920671, 25.44713671, 42.20140067, 30.33454839, 34.5143683 ,
#        29.89347865, 28.31246409, 25.55033779, 17.94566775, 38.73331956,
#        28.88448797, 22.55953135])

# %%
lr_mae = mean_absolute_error(y_pred, Y_test)
lr_mse = mean_squared_error(y_pred, Y_test)
lr_R2_score = r2_score(y_pred,Y_test)

# %%
print("Mean Absolute Error:",lr_mae)
print("Mean Squared Error:", lr_mse)
print("R2 Score:", lr_R2_score)
# Out:
# Mean Absolute Error: 2.7522655335889157
# Mean Squared Error: 10.626517288741157
# R2 Score: 0.7203222931184059

# %%
lr_train_cross_val = cross_val_score(lr,X_train_scale_pc,Y_train,cv=5).mean()
lr_test_cross_val = cross_val_score(lr, X_test_scale_pc,Y_test,cv=5).mean()

# %%
print("Train Data Cross_Val_Score:",lr_train_cross_val)
print("Test Data Cross_Val_Score:",lr_test_cross_val)
# Out:
# Train Data Cross_Val_Score: 0.9180534861466322
# Test Data Cross_Val_Score: 0.9569138833045706

# %% [markdown]
# # Ridge Model

# %%
rd = Ridge(alpha=1.0)
rd.fit(X_train_scale_pc,Y_train)
# Out:
# Ridge()

# %%
y_pred2 = rd.predict(X_test_scale_pc)

# %%
rd_mae = mean_absolute_error(y_pred2, Y_test)
rd_mse = mean_squared_error(y_pred2, Y_test)
rd_R2_score = r2_score(y_pred2,Y_test)

# %%
print("Mean Absolute Error:",rd_mae)
print("Mean Squared Error:", rd_mse)
print("R2 Score:", rd_R2_score)
# Out:
# Mean Absolute Error: 2.751597486411096
# Mean Squared Error: 10.621565280826374
# R2 Score: 0.7197809502380346

# %%
rd_train_cross_val = cross_val_score(rd,X_train_scale_pc,Y_train,cv=5).mean()
rd_test_cross_val = cross_val_score(rd, X_test_scale_pc,Y_test,cv=5).mean()

# %%
print("Train Data Cross_Val_Score:",rd_train_cross_val)
print("Test Data Cross_Val_Score:",rd_test_cross_val)
# Out:
# Train Data Cross_Val_Score: 0.9184108091324245
# Test Data Cross_Val_Score: 0.9573275029323028

# %% [markdown]
# # Random Forest Regressor

# %%
rf = RandomForestRegressor(max_depth=None, n_estimators=200,random_state=42)
rf.fit(X_train_scale_pc,Y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
rf.score(X_train_scale_pc,Y_train)
# Out:
# 0.9852190249393286

# %%
y_pred3 = rf.predict(X_test_scale_pc)

# %%
rf_mae = mean_absolute_error(y_pred3, Y_test)
rf_mse = mean_squared_error(y_pred3, Y_test)
rf_R2_score = r2_score(y_pred3,Y_test)

# %%
print("Mean Absolute Error:",rf_mae)
print("Mean Squared Error:", rf_mse)
print("R2 Score:", rf_R2_score)
# Out:
# Mean Absolute Error: 2.7518548387096775
# Mean Squared Error: 12.04550443548387
# R2 Score: 0.6588209210517075

# %%
rf_train_cross_val = cross_val_score(rf,X_train_scale_pc,Y_train,cv=5).mean()
rf_test_cross_val = cross_val_score(rf, X_test_scale_pc,Y_test,cv=5).mean()

# %%
print("Train Data Cross_Val_Score:",rf_train_cross_val)
print("Test Data Cross_Val_Score:",rf_test_cross_val)
# Out:
# Train Data Cross_Val_Score: 0.875806031414076
# Test Data Cross_Val_Score: 0.7661525241055658

# %% [markdown]
# # Decision Tree Regressor

# %%
dt = DecisionTreeRegressor(max_depth=5,min_samples_leaf=1,min_samples_split=10)
dt.fit(X_train_scale_pc,Y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, min_samples_split=10)

# %%
y_pred4 = dt.predict(X_test_scale_pc)

# %%
dt_mae = mean_absolute_error(y_pred4, Y_test)
dt_mse = mean_squared_error(y_pred4, Y_test)
dt_R2_score = r2_score(y_pred4,Y_test)

# %%
print("Mean Absolute Error:",dt_mae)
print("Mean Squared Error:", dt_mse)
print("R2 Score:", dt_R2_score)
# Out:
# Mean Absolute Error: 3.0026061304287115
# Mean Squared Error: 15.869171877106398
# R2 Score: 0.6702239746416003

# %%
dt_train_cross_val = cross_val_score(dt,X_train_scale_pc,Y_train,cv=5).mean()
dt_test_cross_val = cross_val_score(dt, X_test_scale_pc,Y_test,cv=5).mean()

# %%
print("Train Data Cross_Val_Score:",dt_train_cross_val)
print("Test Data Cross_Val_Score:",dt_test_cross_val)
# Out:
# Train Data Cross_Val_Score: 0.7821736969546758
# Test Data Cross_Val_Score: 0.6488463532272314

# %% [markdown]
# Thus, the Linear Regression Model and Ridge Model performance better when compared to Random Forest and Decision Tree Regressors
